# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#   candidate_id gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0        CAN_1   Male   35           170         165.35                1.0
# 1        CAN_2   Male   30           180         176.37                0.9
# 2        CAN_3   Male   40           165         165.35                1.2
# 3        CAN_4   Male   50           175         176.37                1.5
# 4        CAN_5   Male   50           165         132.28                1.0
#
#    right_eyesight_lvl   can_hear_left_ear  can_hear_right_ear  \
# 0                 1.0  Slightly Defective  Slightly Defective
# 1                 1.2  Slightly Defective  Slightly Defective
# 2                 1.5  Slightly Defective  Slightly Defective
# 3                 1.2  Slightly Defective  Slightly Defective
# 4                 1.2  Slightly Defective  Slightly Defective
#
#    blood_pressure_lvl1  ...  bad_cholestrol_lvl  hemoglobin_lvl  urea_lvl  \
# ...

# %%
df.dropna( inplace=True)

# %%
df.describe()
# Out:
#                 age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# count  18150.000000  18150.000000   18150.000000       18150.000000
# mean      47.519008    162.718182     139.722107           0.981488
# std       14.121336      9.725766      27.664489           0.601269
# min       20.000000    125.000000      66.140000           0.100000
# 25%       35.000000    155.000000     121.250000           0.700000
# 50%       45.000000    165.000000     132.280000           1.000000
# 75%       55.000000    170.000000     154.320000           1.200000
# max       85.000000    200.000000     286.600000           9.900000
#
#        right_eyesight_lvl  blood_pressure_lvl1  blood_pressure_lvl2  \
# count        18150.000000         18150.000000         18150.000000
# mean             0.976275           122.501212            76.112231
# std              0.555615            14.631148             9.933534
# min              0.100000            75.000000            42.000000
# ...

# %%
df_new=df.drop('candidate_id',axis=1)

# %%
df_new.head()
# Out:
#   gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0   Male   35           170         165.35                1.0
# 1   Male   30           180         176.37                0.9
# 2   Male   40           165         165.35                1.2
# 3   Male   50           175         176.37                1.5
# 4   Male   50           165         132.28                1.0
#
#    right_eyesight_lvl   can_hear_left_ear  can_hear_right_ear  \
# 0                 1.0  Slightly Defective  Slightly Defective
# 1                 1.2  Slightly Defective  Slightly Defective
# 2                 1.5  Slightly Defective  Slightly Defective
# 3                 1.2  Slightly Defective  Slightly Defective
# 4                 1.2  Slightly Defective  Slightly Defective
#
#    blood_pressure_lvl1  blood_pressure_lvl2  ...  bad_cholestrol_lvl  \
# 0                120.0                 80.0  ...               126.0
# 1                130.0                 82.0  ...               148.0
# ...

# %%
sns.catplot(data=df, x="gender", y="triglyceride_lvl", kind="bar",col='residential_area')
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="can_hear_right_ear", y="triglyceride_lvl", kind="violin")
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="smoking_habit", y="triglyceride_lvl", hue="gender", kind="point",col='residential_area')
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="drinking_habit", y="triglyceride_lvl", hue="gender", kind="point",col='residential_area')
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="residential_area", y="triglyceride_lvl", hue="gender", kind="bar")
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="residential_area", y="triglyceride_lvl", hue="gender", kind="box")
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="smoking_habit", y="triglyceride_lvl", hue="gender", kind="point",col='drinking_habit')
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="smoking_habit", y="triglyceride_lvl", hue="gender", kind="bar",col='drinking_habit')
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_new["gender"].value_counts()
# Out:
# gender
# Male      9671
# Female    8479
# Name: count, dtype: int64

# %%
df_new['gender'].replace(['Male', 'Female'],
                        [1, 0], inplace=True)

# %%
df_new['gender']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 22395    0
# 22396    1
# 22397    0
# 22398    1
# 22399    1
# Name: gender, Length: 18150, dtype: int64

# %%
df.head()
# Out:
#   candidate_id gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0        CAN_1   Male   35           170         165.35                1.0
# 1        CAN_2   Male   30           180         176.37                0.9
# 2        CAN_3   Male   40           165         165.35                1.2
# 3        CAN_4   Male   50           175         176.37                1.5
# 4        CAN_5   Male   50           165         132.28                1.0
#
#    right_eyesight_lvl   can_hear_left_ear  can_hear_right_ear  \
# 0                 1.0  Slightly Defective  Slightly Defective
# 1                 1.2  Slightly Defective  Slightly Defective
# 2                 1.5  Slightly Defective  Slightly Defective
# 3                 1.2  Slightly Defective  Slightly Defective
# 4                 1.2  Slightly Defective  Slightly Defective
#
#    blood_pressure_lvl1  ...  bad_cholestrol_lvl  hemoglobin_lvl  urea_lvl  \
# ...

# %%
#smoking_habit
df_new["smoking_habit"].value_counts()
# Out:
# smoking_habit
# Does not Smoke         10985
# Chain Smoker            3991
# Occassionaly Smokes     3174
# Name: count, dtype: int64

# %%
df_new["smoking_habit"].replace(['Does not Smoke', 'Occassionaly Smokes','Chain Smoker'],
                        [0,1,2], inplace=True)

# %%
df_new["drinking_habit"].value_counts()
# Out:
# drinking_habit
# N    9098
# Y    9052
# Name: count, dtype: int64

# %%
df_new["drinking_habit"].replace(['Y', 'N'],
                        [0,1], inplace=True)

# %%
df_new["residential_area"].value_counts()
# Out:
# residential_area
# Urban    6083
# Town     6038
# Rural    6029
# Name: count, dtype: int64

# %%
df_new["residential_area"].replace(['Urban', 'Town','Rural'],
                        [0,2,1], inplace=True)

# %%
df_new.head()
# Out:
#    gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0       1   35           170         165.35                1.0
# 1       1   30           180         176.37                0.9
# 2       1   40           165         165.35                1.2
# 3       1   50           175         176.37                1.5
# 4       1   50           165         132.28                1.0
#
#    right_eyesight_lvl   can_hear_left_ear  can_hear_right_ear  \
# 0                 1.0  Slightly Defective  Slightly Defective
# 1                 1.2  Slightly Defective  Slightly Defective
# 2                 1.5  Slightly Defective  Slightly Defective
# 3                 1.2  Slightly Defective  Slightly Defective
# 4                 1.2  Slightly Defective  Slightly Defective
#
#    blood_pressure_lvl1  blood_pressure_lvl2  ...  bad_cholestrol_lvl  \
# 0                120.0                 80.0  ...               126.0
# 1                130.0                 82.0  ...               148.0
# ...

# %%
df_new
# Out:
#        gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0           1   35           170         165.35                1.0
# 1           1   30           180         176.37                0.9
# 2           1   40           165         165.35                1.2
# 3           1   50           175         176.37                1.5
# 4           1   50           165         132.28                1.0
# ...       ...  ...           ...            ...                ...
# 22395       0   50           175         110.23                0.8
# 22396       1   30           165         165.35                0.5
# 22397       0   65           150         132.28                0.8
# 22398       1   50           170         121.25                1.0
# 22399       1   45           170         165.35                1.2
#
#        right_eyesight_lvl   can_hear_left_ear  can_hear_right_ear  \
# 0                     1.0  Slightly Defective  Slightly Defective
# ...

# %%
df_new["can_hear_left_ear"
      
      ].value_counts()
# Out:
# can_hear_left_ear
# Slightly Defective    17621
# Highly Defective        529
# Name: count, dtype: int64

# %%
#"can_hear_right_ear"
df_new["can_hear_right_ear"
      
      ].value_counts()
# Out:
# can_hear_right_ear
# Slightly Defective    17616
# Highly Defective        534
# Name: count, dtype: int64

# %%
df_new["can_hear_right_ear"].replace(['Slightly Defective',' Highly Defective'],[0,1])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 22395    0
# 22396    0
# 22397    0
# 22398    0
# 22399    0
# Name: can_hear_right_ear, Length: 18150, dtype: object

# %%
df_new["can_hear_left_ear"].replace(['Slightly Defective',' Highly Defective'],
                        [0,1])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 22395    0
# 22396    0
# 22397    0
# 22398    0
# 22399    0
# Name: can_hear_left_ear, Length: 18150, dtype: object

# %%
df_new
# Out:
#        gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0           1   35           170         165.35                1.0
# 1           1   30           180         176.37                0.9
# 2           1   40           165         165.35                1.2
# 3           1   50           175         176.37                1.5
# 4           1   50           165         132.28                1.0
# ...       ...  ...           ...            ...                ...
# 22395       0   50           175         110.23                0.8
# 22396       1   30           165         165.35                0.5
# 22397       0   65           150         132.28                0.8
# 22398       1   50           170         121.25                1.0
# 22399       1   45           170         165.35                1.2
#
#        right_eyesight_lvl   can_hear_left_ear  can_hear_right_ear  \
# 0                     1.0  Slightly Defective  Slightly Defective
# ...

# %%
df_new=df_new.drop('can_hear_right_ear',axis=1)

# %%
df_new=df_new.drop('can_hear_left_ear',axis=1)

# %%
df_new.head()
# Out:
#    gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0       1   35           170         165.35                1.0
# 1       1   30           180         176.37                0.9
# 2       1   40           165         165.35                1.2
# 3       1   50           175         176.37                1.5
# 4       1   50           165         132.28                1.0
#
#    right_eyesight_lvl  blood_pressure_lvl1  blood_pressure_lvl2  glucose_lvl  \
# 0                 1.0                120.0                 80.0         99.0
# 1                 1.2                130.0                 82.0        106.0
# 2                 1.5                120.0                 70.0         98.0
# 3                 1.2                145.0                 87.0         95.0
# 4                 1.2                138.0                 82.0        101.0
#
#    total_cholestrol  ...  bad_cholestrol_lvl  hemoglobin_lvl  urea_lvl  \
# ...

# %%
df_new.drop('triglyceride_lvl',inplace=True,axis=1)

# %%
Y=df["triglyceride_lvl"]

# %%
Y
# Out:
# 0         92.0
# 1        121.0
# 2        104.0
# 3        106.0
# 4        104.0
#          ...
# 22395     52.0
# 22396    195.0
# 22397    328.0
# 22398     97.0
# 22399    139.0
# Name: triglyceride_lvl, Length: 18150, dtype: float64

# %%
X_train, X_test, y_train,  y_test = train_test_split(df_new,Y ,  
                          random_state=104, 
                          train_size=0.8, shuffle=True)

# %%
X_train
# Out:
#        gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 9691        1   60           170         165.35                1.0
# 3565        1   45           165         154.32                1.0
# 16094       1   30           175         220.46                1.0
# 409         0   80           145         110.23                0.5
# 17555       1   35           170         154.32                0.8
# ...       ...  ...           ...            ...                ...
# 17481       1   70           160         154.32                0.5
# 9756        1   45           180         165.35                0.7
# 7780        0   60           160         110.23                0.8
# 21116       0   40           165          99.21                1.5
# 10218       1   40           160         132.28                0.8
#
#        right_eyesight_lvl  blood_pressure_lvl1  blood_pressure_lvl2  \
# 9691                  0.1                126.0                 82.0
# ...

# %%
y_train
# Out:
# 9691      62.0
# 3565     500.0
# 16094    167.0
# 409      114.0
# 17555     80.0
#          ...
# 17481    110.0
# 9756      80.0
# 7780     130.0
# 21116     47.0
# 10218     86.0
# Name: triglyceride_lvl, Length: 14520, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# 493.282572607854

# %%
coeff_parameter = pd.DataFrame(model.coef_,df_new.columns,columns=['Coefficient'])
coeff_parameter
# Out:
#                      Coefficient
# gender                 47.578223
# age                    -0.301111
# height_in_cm           -4.738168
# weight_in_lbs           1.109885
# left_eyesight_lvl       0.066470
# right_eyesight_lvl      1.254379
# blood_pressure_lvl1    -0.022850
# blood_pressure_lvl2     0.227688
# glucose_lvl             0.282012
# total_cholestrol        1.272243
# good_cholestrol_lvl     0.363299
# bad_cholestrol_lvl     -1.039354
# hemoglobin_lvl          1.797341
# urea_lvl                2.334224
# creatinine_lvl          4.492858
# liver_enzyme_lvl1      -0.135691
# liver_enzyme_lvl2       0.287696
# smoking_habit          11.585751
# drinking_habit          4.221490
# residential_area        0.709380

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([238.69310385, 102.90194385, 142.99239293, ...,  33.82560399,
#        101.30012311,  91.80427511])

# %%
X_train
# Out:
#        gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 9691        1   60           170         165.35                1.0
# 3565        1   45           165         154.32                1.0
# 16094       1   30           175         220.46                1.0
# 409         0   80           145         110.23                0.5
# 17555       1   35           170         154.32                0.8
# ...       ...  ...           ...            ...                ...
# 17481       1   70           160         154.32                0.5
# 9756        1   45           180         165.35                0.7
# 7780        0   60           160         110.23                0.8
# 21116       0   40           165          99.21                1.5
# 10218       1   40           160         132.28                0.8
#
#        right_eyesight_lvl  blood_pressure_lvl1  blood_pressure_lvl2  \
# 9691                  0.1                126.0                 82.0
# ...

# %%
df_test=pd.read_csv('test.csv')

# %%
df_test.dropna( inplace=True)

# %%
df_new_test=df_test.drop('candidate_id',axis=1)

# %%
df_new_test
# Out:
#       gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0     Female   50           155         121.25                1.2
# 2     Female   40           155          99.21                0.9
# 3       Male   50           175         176.37                1.5
# 4       Male   45           180         143.30                1.0
# 6       Male   45           180         198.42                0.4
# ...      ...  ...           ...            ...                ...
# 9595    Male   75           170         121.25                1.0
# 9596  Female   40           155         165.35                1.0
# 9597    Male   35           175         143.30                0.9
# 9598  Female   60           155          99.21                0.9
# 9599    Male   30           170         176.37                1.0
#
#       right_eyesight_lvl   can_hear_left_ear  can_hear_right_ear  \
# 0                    0.9  Slightly Defective  Slightly Defective
# ...

# %%
df_new_test=df_new_test.drop('can_hear_right_ear',axis=1)
df_new_test
# Out:
#       gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0     Female   50           155         121.25                1.2
# 2     Female   40           155          99.21                0.9
# 3       Male   50           175         176.37                1.5
# 4       Male   45           180         143.30                1.0
# 6       Male   45           180         198.42                0.4
# ...      ...  ...           ...            ...                ...
# 9595    Male   75           170         121.25                1.0
# 9596  Female   40           155         165.35                1.0
# 9597    Male   35           175         143.30                0.9
# 9598  Female   60           155          99.21                0.9
# 9599    Male   30           170         176.37                1.0
#
#       right_eyesight_lvl   can_hear_left_ear  blood_pressure_lvl1  \
# 0                    0.9  Slightly Defective                140.0
# ...

# %%
df_new_test=df_new_test.drop('can_hear_left_ear',axis=1)

# %%
df_new_test
# Out:
#       gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0     Female   50           155         121.25                1.2
# 2     Female   40           155          99.21                0.9
# 3       Male   50           175         176.37                1.5
# 4       Male   45           180         143.30                1.0
# 6       Male   45           180         198.42                0.4
# ...      ...  ...           ...            ...                ...
# 9595    Male   75           170         121.25                1.0
# 9596  Female   40           155         165.35                1.0
# 9597    Male   35           175         143.30                0.9
# 9598  Female   60           155          99.21                0.9
# 9599    Male   30           170         176.37                1.0
#
#       right_eyesight_lvl  blood_pressure_lvl1  blood_pressure_lvl2  \
# 0                    0.9                140.0                 90.0
# ...

# %%
df_new_test['gender'].replace(['Male', 'Female'],
                        [1, 0], inplace=True)

# %%
df_new_test["smoking_habit"].replace(['Does not Smoke', 'Occassionaly Smokes','Chain Smoker'],
                        [0,1,2], inplace=True)

# %%
df_new_test["drinking_habit"].replace(['Y', 'N'],
                        [0,1], inplace=True)

# %%
df_new_test["residential_area"].replace(['Urban', 'Town','Rural'],
                        [0,2,1], inplace=True)

# %%
df_new_test
# Out:
#       gender  age  height_in_cm  weight_in_lbs  left_eyesight_lvl  \
# 0          0   50           155         121.25                1.2
# 2          0   40           155          99.21                0.9
# 3          1   50           175         176.37                1.5
# 4          1   45           180         143.30                1.0
# 6          1   45           180         198.42                0.4
# ...      ...  ...           ...            ...                ...
# 9595       1   75           170         121.25                1.0
# 9596       0   40           155         165.35                1.0
# 9597       1   35           175         143.30                0.9
# 9598       0   60           155          99.21                0.9
# 9599       1   30           170         176.37                1.0
#
#       right_eyesight_lvl  blood_pressure_lvl1  blood_pressure_lvl2  \
# 0                    0.9                140.0                 90.0
# ...

# %%
predictions = model.predict(df_new_test)
predictions=
# Out:
# array([113.27831475,  77.47111521, 152.82360173, ..., 110.18858134,
#        121.01359757, 216.03743138])

# %%
df_test['triglyceride_lvl']=predictions
df

# %%
df_test
# Out:
#      candidate_id  gender  age  height_in_cm  weight_in_lbs  \
# 0       CAN_22401  Female   50           155         121.25
# 2       CAN_22403  Female   40           155          99.21
# 3       CAN_22404    Male   50           175         176.37
# 4       CAN_22405    Male   45           180         143.30
# 6       CAN_22407    Male   45           180         198.42
# ...           ...     ...  ...           ...            ...
# 9595    CAN_31996    Male   75           170         121.25
# 9596    CAN_31997  Female   40           155         165.35
# 9597    CAN_31998    Male   35           175         143.30
# 9598    CAN_31999  Female   60           155          99.21
# 9599    CAN_32000    Male   30           170         176.37
#
#       left_eyesight_lvl  right_eyesight_lvl   can_hear_left_ear  \
# 0                   1.2                 0.9  Slightly Defective
# 2                   0.9                 1.2  Slightly Defective
# ...

# %%
df_solution=df_test['candidate_id']

# %%
df_solutions = df_test[['candidate_id', 'triglyceride_lvl']].copy()

# %%
df_solutions
# Out:
#      candidate_id  triglyceride_lvl
# 0       CAN_22401        113.278315
# 2       CAN_22403         77.471115
# 3       CAN_22404        152.823602
# 4       CAN_22405        108.949483
# 6       CAN_22407        110.557530
# ...           ...               ...
# 9595    CAN_31996         72.959181
# 9596    CAN_31997        211.063207
# 9597    CAN_31998        110.188581
# 9598    CAN_31999        121.013598
# 9599    CAN_32000        216.037431
#
# [7808 rows x 2 columns]

# %%
df_solutions.to_csv('Hackerearth_solution.csv', index = True)

# %%
df
# Out:
#       candidate_id  gender  age  height_in_cm  weight_in_lbs  \
# 0            CAN_1    Male   35           170         165.35
# 1            CAN_2    Male   30           180         176.37
# 2            CAN_3    Male   40           165         165.35
# 3            CAN_4    Male   50           175         176.37
# 4            CAN_5    Male   50           165         132.28
# ...            ...     ...  ...           ...            ...
# 22395    CAN_22396  Female   50           175         110.23
# 22396    CAN_22397    Male   30           165         165.35
# 22397    CAN_22398  Female   65           150         132.28
# 22398    CAN_22399    Male   50           170         121.25
# 22399    CAN_22400    Male   45           170         165.35
#
#        left_eyesight_lvl  right_eyesight_lvl   can_hear_left_ear  \
# 0                    1.0                 1.0  Slightly Defective
# 1                    0.9                 1.2  Slightly Defective
# ...

# %%
df.drop(" ",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df.drop(" ",axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...
